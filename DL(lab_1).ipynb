# %%
import tensorflow as tf
import numpy as np

#step-1 convert data to NumPy arrays
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

#step-2 Define model using input layer
model=tf.keras.Sequential([
    tf.keras.Input(shape=(1,)),
    tf.keras.layers.Dense(1)
])

#step-3 Compile the model
model.compile(optimizer='sgd',loss='mean_squared_error')

#step-4 Train the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 86.7503
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 60.2481
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 41.8584
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 29.0979
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 20.2434
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 14.0990
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 9.8353
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 6.8765
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 4.8231
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 3.3980

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

#step1 convert data to numpy arrays
x=np.array([1,2,3,4],dtype=float)
y=np.array([2,4,6,8],dtype=float)

#step2 Define the model
model=Sequential([
    Dense(1,input_shape=(1,))
])

#step3 compile the model
model.compile(optimizer='sgd',loss='mse')

#step4 fit the model
model.fit(x,y,epochs=10)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - loss: 9.2885
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 6.4509
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4.4818
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3.1156
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 2.1675
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.5096
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.0531
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.7363
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.5164
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.3638

# %%
import torch
import torch.nn as nn
import torch.optim as optim

#Define  a simple linear model
model=nn.Linear(1,1)

#loss and optimizer
criterion=nn.MSELoss()
optimizer=optim.SGD(model.parameters(),lr=0.01)

#Dummy data
x=torch.tensor([[1.],[2.],[3.],[4.]])
y=torch.tensor([[2.],[4.],[6.],[8.]])

#Training loop
for epoch in range(10):
  optimizer.zero_grad()
  outputs=model(x)
  loss=criterion(outputs,y)
  loss.backward()
  optimizer.step()
  print(f"Epoch{epoch+1},Loss:{loss.item()}")
# Out:
# Epoch1,Loss:8.55325984954834
# Epoch2,Loss:5.95205020904541
# Epoch3,Loss:4.147024154663086
# Epoch4,Loss:2.8944523334503174
# Epoch5,Loss:2.0252180099487305
# Epoch6,Loss:1.4219748973846436
# Epoch7,Loss:1.0032966136932373
# Epoch8,Loss:0.7126854658126831
# Epoch9,Loss:0.5109378099441528
# Epoch10,Loss:0.3708510994911194
