# %%
# Step 1: Import Libraries
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Step 2: Load CIFAR-10
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Step 3: Data Augmentation

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

datagen.fit(x_train)

# %%
# Step 4: Build CNN with Dropout
model = models.Sequential([
    # Conv Block 1
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),

    # Conv Block 2
    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(2,2),
    layers.Dropout(0.25),

    # Fully Connected
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),

    layers.Dense(10, activation='softmax')
])

# %%
# Step 5: Compile Model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Step 6: Train Model
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    epochs=10,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 121ms/step - accuracy: 0.5777 - loss: 1.1917 - val_accuracy: 0.6685 - val_loss: 0.9523
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 96s 123ms/step - accuracy: 0.5846 - loss: 1.1790 - val_accuracy: 0.6536 - val_loss: 0.9770
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.5833 - loss: 1.1841 - val_accuracy: 0.6630 - val_loss: 0.9609
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.5989 - loss: 1.1553 - val_accuracy: 0.6465 - val_loss: 1.0189
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.5952 - loss: 1.1504 - val_accuracy: 0.6827 - val_loss: 0.9149
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.5970 - loss: 1.1535 - val_accuracy: 0.6939 - val_loss: 0.8978
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.6077 - loss: 1.1315 - val_accuracy: 0.6816 - val_loss: 0.9222
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.6064 - loss: 1.1188 - val_accuracy: 0.6954 - val_loss: 0.8718
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 94s 121ms/step - accuracy: 0.6081 - loss: 1.1199 - val_accuracy: 0.7092 - val_loss: 0.8462
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 93s 119ms/step - accuracy: 0.6156 - loss: 1.1029 - val_accuracy: 0.6872 - val_loss: 0.8914

# %%
# Step 7: Evaluate
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6828 - loss: 0.8926
# Test Accuracy: 0.6872000098228455
